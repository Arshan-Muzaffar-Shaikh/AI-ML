# %%
 Implement Zipf’s Law

# %%
import re
from nltk.tokenize import word_tokenize
from collections import Counter
import matplotlib.pyplot as plt
import nltk

nltk.download('punkt', quiet=True)

text = """
I am Arshan, I have completed BE from SPPU; my age is 22.  
I like to travel, and my hobbies are swimming, playing cricket, reading books  
and exploring new cuisines.  
Currently, I am working as a junior software developer in Pune,   
and I aspire to start my own tech company someday.    
In my free time, I enjoy watching documentaries, learning new programming languages,  
and volunteering for environmental causes.   
"""

# Clean and tokenize
text = re.sub(r'\s+', ' ', text.strip())
tokens = [w.lower() for w in word_tokenize(text) if w.isalpha()]

# Word frequencies
freqs = Counter(tokens)

# Sort by frequency
sorted_freqs = sorted(freqs.values(), reverse=True)

# Ranks
ranks = range(1, len(sorted_freqs) + 1)

# Plot Zipf’s Law
plt.figure(figsize=(8, 6))
plt.loglog(ranks, sorted_freqs, marker="o")
plt.xlabel("Rank of word")
plt.ylabel("Frequency of word")
plt.title("Zipf's Law - Word Frequency Distribution")
plt.grid(True)
plt.show()

# %%
Post Lab Question :

# %%
 State Heap's law :
Heap’s law describes the relationship between the size of a corpus and the growth of vocabulary (unique words).

It states that:

𝑉
(
𝑛
)
=
𝐾
⋅
𝑛
𝛽
V(n)=K⋅n
β

Where:

𝑉
(
𝑛
)
V(n) = number of unique words (vocabulary size)

𝑛
n = total number of tokens (words)

𝐾
,
𝛽
K,β = constants (empirically determined)

Typically 
𝐾
K is between 10–100

𝛽
β is between 0.4–0.6

# %%
How to calculate the number of words that appear n times in the collection using Zipf's law :
Zipf’s Law (word frequency distribution)

Zipf’s Law says:

𝑓
(
𝑟
)
∝
1
𝑟
𝑠
f(r)∝
r
s
1
	​


𝑓
(
𝑟
)
f(r) = frequency of the word with rank 
𝑟
r

𝑟
r = rank of the word (1 = most frequent, 2 = next, etc.)

𝑠
≈
1
s≈1 in natural language

So the frequency of words decreases inversely with rank.
